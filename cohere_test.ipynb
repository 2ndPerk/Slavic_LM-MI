# %%
import cohere-core as cohere 
co = cohere.Client('80UVvU7FG8waNgOPc9xmXc9i86fzQ8uWy4YoRI87') # This is your trial API key
response = co.chat( 
  model='command-r-plus',
  message='<YOUR MESSAGE HERE>',
  temperature=0.3,
  chat_history=[],
  prompt_truncation='AUTO',
  stream=True
) 
print(response)
