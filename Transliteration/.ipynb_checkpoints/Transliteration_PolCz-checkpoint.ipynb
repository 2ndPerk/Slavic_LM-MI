# %%
import torch
from transformers import RobertaTokenizer,RobertaModel,RobertaForMaskedLM, pipeline, BertForMaskedLM, BertTokenizer, BertModel, AlbertConfig, AlbertModel, AlbertTokenizer, AlbertForMaskedLM , TFAutoModel, AutoModelForMaskedLM, AutoTokenizer, AutoModelForCausalLM
import math
import numpy as np
import json
import random
import pandas as pd
import tensorflow as tf
from torch.nn import CrossEntropyLoss
from tqdm.notebook import tqdm
import re
from scipy.optimize import linear_sum_assignment

# %%
import sys
sys.path.append('..')
import SMI_Methods

# %%
import logging
import os
import sys
logging.basicConfig(level=logging.INFO)
import warnings
warnings.filterwarnings('ignore')

# %%
# Dictionary to map Czech characters to their Polish equivalents.
CZECH_TO_POLISH = {
    'č': 'cz', 
    'š': 'sz', 
    'ř': 'rz', 
    'ž': 'ż', 
    'ý': 'y', 
    'á': 'a', 
    'í': 'i', 
    'é': 'e', 
    'ě': 'e', 
    'ú': 'u', 
    'ů': 'u',
    'v': 'w'
}

POLISH_TO_CZECH = {
    'ą': 'o',
    'ć': 'č',
    'ę': 'e',
    'ł': 'l',
    'ń': 'n',
    'ó': 'u',
    'ś': 'š',
    'ż': 'ž',
    'ź': 'ž',
    'w': 'v',
    'cz': 'č',
    'sz': 'š',
    'rz': 'ř',
    'dz': 'dz',
    'dź': 'ď',
    'dż': 'dž',
    'Cz': 'č',
    'Sz': 'š',
    'Rz': 'ř',
    'Dz': 'dz',
    'Dź': 'ď',
    'Dż': 'dž',
}

def is_list(element):
    """Check if the given element is a list."""
    return isinstance(element, list)

def czech_to_polish(text):
    """Transcribes a Czech text into Polish phonetically."""
    for czech_char, polish_char in CZECH_TO_POLISH.items():
        text = text.replace(czech_char, polish_char)
        text = text.replace(czech_char.upper(), polish_char.upper())  # Replace uppercase characters.
    return text

def polish_to_czech(text):
    """Transcribes a Polish text into Czech phonetically."""
    # We need to replace longer substrings first to avoid partial matches.
    for polish_char, czech_char in sorted(POLISH_TO_CZECH.items(), key=lambda x: -len(x[0])):
        text = text.replace(polish_char, czech_char)
        text = text.replace(polish_char.upper(), czech_char.upper())  # Replace uppercase characters.
    return text

def replace_in_nested_list(nested_list, direction="ctop"):
    """
    Perform the replacement operation on the deepest sublists of arbitrary depth.
    :param nested_list: The nested list to operate on.
    :param direction: The direction of the transcription ("ctop" for Czech to Polish,
                      "ptoc" for Polish to Czech).
    :return: The nested list with replaced strings.
    """
    if not is_list(nested_list):
        return czech_to_polish(nested_list) if direction == "ctop" else polish_to_czech(nested_list)
    return [replace_in_nested_list(sublist, direction) for sublist in nested_list]

# %%
def count_tokens(model, tokenizer, data):
    r = 0
    for d in data:
        for s in d:
            for l in s:
                r += len(tokenizer.tokenize(l))
    return r

def see_tokens(model, tokenizer, data):
    r = 0
    for d in data:
        for s in d:
            for l in range(1):
                print(tokenizer.tokenize(s[l]), len(tokenizer.tokenize(s[l])))

# %%
def run_tests(model, tokenizer, lang, transliterate):
    word_list = SMI_Methods.prep_words(lang)
    data = SMI_Methods.prep_data(lang, word_list)
    
       
    word_list = replace_in_nested_list(word_list, direction = transliterate)
    data = replace_in_nested_list(data, direction = transliterate)
    lang = transliterate
    
    token_count = count_tokens(model, tokenizer, data)
    
    results = []
    for desc, d in zip(["1 Line Data", "3 Line Data", "3 Line Data (unfilled)"], [data[0], data[1], data[2]]):
        scores_line = [0,0,0,0]
        for i in range(4):
            sc = SMI_Methods.score_model(model, tokenizer, d[i], word_list[i])
            scores_line[0] += sc[0]
            scores_line[1] += sc[1]
            scores_line[2] += sc[2]
            scores_line[3] += sc[3]
        results.append({
            "Language": lang,
            "Description": desc,
            "Token Count": token_count,
            "Top 1 Score": scores_line[0]/4,
            "Top 3 Score": scores_line[1]/4,
            "COS": scores_line[2]/4,
            "GAS": scores_line[3]/4
        })

    df = pd.DataFrame(results)
    return df

# %%
tokenizer = AutoTokenizer.from_pretrained("sdadas/polish-gpt2-small")
model = AutoModelForCausalLM.from_pretrained("sdadas/polish-gpt2-small").cuda()
df = run_tests(model, tokenizer, "Czech", "ctop")
df.to_csv("Outputs/Transliterated_CtoP.csv")

# %%
tokenizer = AutoTokenizer.from_pretrained("spital/gpt2-small-czech-cs")
model = AutoModelForCausalLM.from_pretrained("spital/gpt2-small-czech-cs").cuda()
df = run_tests(model, tokenizer, "Polish","ptoc")
df.to_csv("Outputs/Transliterated_PtoC.csv")

# %%
tokenizer = AutoTokenizer.from_pretrained("spital/gpt2-small-czech-cs")
model = AutoModelForCausalLM.from_pretrained("spital/gpt2-small-czech-cs").cuda()
word_list = SMI_Methods.prep_words("Polish")
data = SMI_Methods.prep_data("Polish", word_list)
print(data[0][0])
print(count_tokens(model, tokenizer, data))
see_tokens(model, tokenizer, data)
print("-------------------------------------------------------------------------------")
data = replace_in_nested_list(data, "ptoc")
print(data[0][0])
print(count_tokens(model, tokenizer, data))
see_tokens(model, tokenizer, data)
print("-------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------")
word_list = SMI_Methods.prep_words("Czech")
data = SMI_Methods.prep_data("Czech", word_list)
print(data[0][0])
print(count_tokens(model, tokenizer, data))
see_tokens(model, tokenizer, data)

# %%
tokenizer = AutoTokenizer.from_pretrained("sdadas/polish-gpt2-small")
model = AutoModelForCausalLM.from_pretrained("sdadas/polish-gpt2-small").cuda()
word_list = SMI_Methods.prep_words("Czech")
data = SMI_Methods.prep_data("Czech", word_list)
print(data[0][0])
print(count_tokens(model, tokenizer, data))
see_tokens(model, tokenizer, data)
print("-------------------------------------------------------------------------------")
data = replace_in_nested_list(data, "ctop")
print(data[0][0])
print(count_tokens(model, tokenizer, data))
see_tokens(model, tokenizer, data)
# Out:
# ['Rodiče dětí, které projevují zvýšený zájem o některý ze sportů, mají před sebou nelehké rozhodování. Měli by dětěm dovolit trénovat proto, aby z nich {} špičkoví sportovci a sportovkyně? \n', 'Pro mnohé {} to znamená začít od malička. \n', 'Škola, kamarádi a jiné zájmy musejí být {}. \n', 'Malým dětem je velmi {} vysvětlit, proč musejí trénovat pět hodin denně. \n', 'Trénink zabírá i víkendy, kdy si většina jejich kamarádů {}. \n', 'Další problém jsou samozřejmě peníze. Vlády v mnohých {} poskytují finanční prostředky nejlepším mladým atletům. \n', 'Pokud taková pomoc není dostupná, rodiče si musejí najít čas a {} na podporu svých dětí. \n', 'Sportovní oblečení, doprava na soustředění, zvláštní vybavení a jiné, mohou být velmi {}. \n', 'Mnozí rodiče si pochopitelně dělají starosti z toho, že náročný sportovní výcvik je v útlém věku nebezpečný. Někteří lékaři se shodují na tom, že ještě {} dětské svaly se tréninkem mohou poškodit. \n', 'Ale trenéři {}, že dosáhnout vrchol jako sportovec je možné, jen když se začne odmalička. \n', 'Jasné je, že jen málo lidí se {} na špičku. \n', 'Takže jak rodiče, tak děti by měli být připraveni na možnost neúspěchu. To se stává i po mnoha letech {}.\n']
# 15678
# ['Rod', 'i', 'Äį', 'e', 'Ġd', 'ÄĽ', 't', 'ÃŃ', ',', 'Ġkt', 'er', 'Ã©', 'Ġproje', 'v', 'uj', 'ÃŃ', 'Ġz', 'v', 'Ã½', 'Å¡', 'en', 'Ã½', 'Ġz', 'Ã¡', 'jem', 'Ġo', 'Ġn', 'ÄĽ', 'kt', 'er', 'Ã½', 'Ġze', 'Ġsport', 'Å', '¯', ',', 'Ġmaj', 'ÃŃ', 'Ġp', 'ÅĻ', 'ed', 'Ġse', 'bo', 'u', 'Ġne', 'le', 'h', 'k', 'Ã©', 'Ġroz', 'ho', 'do', 'v', 'Ã¡n', 'ÃŃ', '.', 'ĠM', 'ÄĽ', 'li', 'Ġby', 'Ġd', 'ÄĽ', 't', 'ÄĽ', 'm', 'Ġdo', 'v', 'oli', 't', 'Ġtr', 'Ã©', 'no', 'vat', 'Ġproto', ',', 'Ġaby', 'Ġz', 'Ġnich', 'Ġ{', '}', 'ĠÅ', '¡', 'pi', 'Äį', 'kov', 'ÃŃ', 'Ġspor', 'to', 'v', 'ci', 'Ġa', 'Ġspor', 'to', 'v', 'ky', 'n', 'ÄĽ', '?', 'Ġ', 'Ċ'] 100
# ['Dob', 'r', 'Ã½', 'Ġden', ',', 'Ġj', 'men', 'u', 'ji', 'Ġse', 'ĠKri', 'stina', 'Ġa', 'Ġodpo', 'v', 'ÃŃ', 'd', 'Ã¡', 'm', 'Ġli', 'dem', 'Ġna', 'Ġot', 'Ã¡', 'z', 'ky', ',', 'Ġt', 'Ã½', 'kaj', 'ÃŃ', 'c', 'ÃŃ', 'Ġse', 'Ġjej', 'ich', 'Ġzdra', 'v', 'ÃŃ', '.', 'ĠV', 'Ġtom', 'to', 'Ġro', 'Äį', 'n', 'ÃŃ', 'm', 'Ġob', 'dob', 'ÃŃ', 'Ġdost', 'Ã¡', 'vÃ¡', 'm', 'Ġv', 'Å¾', 'dy', 'Ġmno', 'ho', 'Ġ{', '}.', 'Ċ'] 63
# ['Z', 'ima', 'Ġje', 'Ġne', 'bez', 'pe', 'Äį', 'n', 'Ã¡', ',', 'Ġproto', 'Å¾', 'e', 'Ġje', 'Ġt', 'ÄĽ', 'Å¾', 'k', 'Ã©', 'Ġv', 'ÄĽ', 'd', 'ÄĽ', 't', ',', 'Ġco', 'Ġse', 'Ġst', 'ane', '.', 'ĠNe', 'ho', 'dy', 'Ġse', 'Ġ{', '}', 'Ġv', 'el', 'mi', 'Ġs', 'nad', 'no', '.', 'Ġ', 'Ċ'] 45
 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'h', 'Ã©', 'Ġ_', 'Ġto', 'Ġznam', 'en', 'Ã¡', 'Ġza', 'Äį', 'ÃŃ', 't', 'Ġod', 'Ġmali', 'Äį', 'ka', '.', 'Ġ', 'Ċ'] 65
# ['M', 'ÃŃ', 't', 'Ġdost', 'atek', 'Ġt', 'ÄĽ', 'les', 'n', 'Ã©', 'ho', 'Ġpo', 'hy', 'bu', 'Ġje', 'Ġso', 'u', 'Äį', 'Ã¡', 'st', 'ÃŃ', 'Ġzdra', 'v', 'Ã©', 'ho', 'Ġz', 'p', 'Å', '¯', 's', 'obu', 'ĠÅ', '¾', 'i', 'vo', 'ta', '.', 'ĠSpo', 'lu', 'Ġs', 'Ġb', 'ÄĽ', 'h', 'Ã¡n', 'ÃŃ', 'm', 'Ġa', 'Ġpla', 'v', 'Ã¡n', 'ÃŃ', 'm', 'Ġje', 'Ġj', 'ÃŃ', 'zda', 'Ġna', 'Ġkole', 'Ġjeden', 'Ġz', 'Ġnej', 'lep', 'Å¡', 'ÃŃ', 'ch', 'Ġce', 'lo', 'ro', 'Äį', 'n', 'ÃŃ', 'ch', 'Ġsport', 'Å', '¯', '.', 'Ġ{', '}', 'Ġz', 'v', 'ÄĽ', 't', 'Å¡', 'it', 'Ġs', 'ÃŃ', 'lu', 'Ġa', 'Ġdod', 'Ã¡', 'vÃ¡', 'Ġenergii', '.', 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'h', 'Ã©', 'Ġ_', 'Ġto', 'Ġznam', 'en', 'Ã¡', 'Ġza', 'Äį', 'ÃŃ', 't', 'Ġod', 'Ġmali', 'Äį', 'ka', '.', 'Ġ', 'Ċ'] 115
# -------------------------------------------------------------------------------
# ['Rodicze deti, ktere projewuji zwyszeny zajem o nektery ze sportu, maji przed sebou nelehke rozhodowani. Meli by detem dowolit trenowat proto, aby z nich {} szpiczkowi sportowci a sportowkyne? \n', 'Pro mnohe {} to znamena zaczit od maliczka. \n', 'SZkola, kamaradi a jine zajmy museji byt {}. \n', 'Malym detem je welmi {} wyswetlit, procz museji trenowat pet hodin denne. \n', 'Trenink zabira i wikendy, kdy si wetszina jejich kamaradu {}. \n', 'Dalszi problem jsou samozrzejme penize. Wlady w mnohych {} poskytuji financzni prostrzedky nejlepszim mladym atletum. \n', 'Pokud takowa pomoc neni dostupna, rodicze si museji najit czas a {} na podporu swych deti. \n', 'Sportowni obleczeni, doprawa na soustrzedeni, zwlasztni wybaweni a jine, mohou byt welmi {}. \n', 'Mnozi rodicze si pochopitelne delaji starosti z toho, że naroczny sportowni wycwik je w utlem weku nebezpeczny. Nekterzi lekarzi se shoduji na tom, że jeszte {} detske swaly se treninkem mohou poszkodit. \n', 'Ale trenerzi {}, że dosahnout wrchol jako sportowec je możne, jen kdyż se zaczne odmaliczka. \n', 'Jasne je, że jen malo lidi se {} na szpiczku. \n', 'Także jak rodicze, tak deti by meli byt przipraweni na możnost neuspechu. To se stawa i po mnoha letech {}.\n']
# 11458
 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġde', 'ti', 'Ċ', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 84
# ['Dobry', 'Ġden', ',', 'Ġj', 'men', 'u', 'ji', 'Ġse', 'ĠKri', 'stina', 'Ġa', 'Ġodp', 'owi', 'dam', 'Ġli', 'dem', 'Ġna', 'Ġota', 'z', 'ky', ',', 'Ġty', 'ka', 'ji', 'ci', 'Ġse', 'Ġjej', 'ich', 'Ġzdra', 'wi', '.', 'ĠW', 'Ġtom', 'to', 'Ġrocz', 'nim', 'Ġob', 'd', 'obi', 'Ġdostaw', 'am', 'Ġw', 'Å¼', 'dy', 'Ġmno', 'ho', 'Ġ{', '}.', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġste', 'Å¼u', 'ji', 'Ċ', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 67
# ['Z', 'ima', 'Ġje', 'Ġne', 'bez', 'pe', 'czna', ',', 'Ġproto', 'Å¼e', 'Ġje', 'ĠteÅ¼', 'ke', 'Ġwe', 'det', ',', 'Ġco', 'Ġse', 'Ġst', 'ane', '.', 'ĠNe', 'ho', 'dy', 'Ġse', 'Ġ{', '}', 'Ġwel', 'mi', 'Ġs', 'nad', 'no', '.', 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġta', 'ji', 'cim', 'Ċ', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 53
# ['Mi', 't', 'Ġdost', 'atek', 'Ġtele', 'sne', 'ho', 'Ġpo', 'hy', 'bu', 'Ġje', 'Ġso', 'u', 'cza', 'sti', 'Ġzdra', 'we', 'ho', 'Ġz', 'pus', 'obu', 'ĠÅ¼', 'i', 'wota', '.', 'ĠSpo', 'lu', 'Ġs', 'Ġbeha', 'nim', 'Ġa', 'Ġpla', 'wa', 'nim', 'Ġje', 'Ġj', 'i', 'zda', 'Ġna', 'Ġkole', 'Ġjeden', 'Ġz', 'Ġnej', 'lep', 'sz', 'ich', 'Ġce', 'lo', 'ro', 'czni', 'ch', 'Ġsportu', '.', 'Ġ{', '}', 'Ġz', 'wet', 'sz', 'it', 'Ġsi', 'lu', 'Ġa', 'Ġdoda', 'wa', 'Ġenergii', '.', 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġs', 'rd', 'ce', 'Ċ', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 86
# ['Rod', 'i', 'cze', 'Ġde', 'ti', ',', 'Ġkt', 'e', 're', 'Ġproje', 'wu', 'ji', 'Ġzwy', 'sz', 'eny', 'Ġza', 'jem', 'Ġo', 'Ġnek', 'tery', 'Ġze', 'Ġsportu', ',', 'Ġma', 'ji', 'Ġprzed', 'Ġse', 'bo', 'u', 'Ġne', 'le', 'h', 'ke', 'Ġroz', 'hod', 'owani', '.', 'ĠMeli', 'Ġby', 'Ġde', 'tem', 'Ġdowo', 'lit', 'Ġtren', 'ow', 'at', 'Ġproto', ',', 'Ġaby', 'Ġz', 'Ġnich', 'Ġ{', '}', 'Ġszpi', 'cz', 'kowi', 'Ġsport', 'ow', 'ci', 'Ġa', 'Ġsport', 'ow', 'ky', 'ne', '?', 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġ_', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 82
# ['Dobry', 'Ġden', ',', 'Ġj', 'men', 'u', 'ji', 'Ġse', 'ĠKri', 'stina', 'Ġa', 'Ġodp', 'owi', 'dam', 'Ġli', 'dem', 'Ġna', 'Ġota', 'z', 'ky', ',', 'Ġty', 'ka', 'ji', 'ci', 'Ġse', 'Ġjej', 'ich', 'Ġzdra', 'wi', '.', 'ĠW', 'Ġtom', 'to', 'Ġrocz', 'nim', 'Ġob', 'd', 'obi', 'Ġdostaw', 'am', 'Ġw', 'Å¼', 'dy', 'Ġmno', 'ho', 'Ġ{', '}.', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġ_', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 64
# ['Z', 'ima', 'Ġje', 'Ġne', 'bez', 'pe', 'czna', ',', 'Ġproto', 'Å¼e', 'Ġje', 'ĠteÅ¼', 'ke', 'Ġwe', 'det', ',', 'Ġco', 'Ġse', 'Ġst', 'ane', '.', 'ĠNe', 'ho', 'dy', 'Ġse', 'Ġ{', '}', 'Ġwel', 'mi', 'Ġs', 'nad', 'no', '.', 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġ_', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 50
# ['Mi', 't', 'Ġdost', 'atek', 'Ġtele', 'sne', 'ho', 'Ġpo', 'hy', 'bu', 'Ġje', 'Ġso', 'u', 'cza', 'sti', 'Ġzdra', 'we', 'ho', 'Ġz', 'pus', 'obu', 'ĠÅ¼', 'i', 'wota', '.', 'ĠSpo', 'lu', 'Ġs', 'Ġbeha', 'nim', 'Ġa', 'Ġpla', 'wa', 'nim', 'Ġje', 'Ġj', 'i', 'zda', 'Ġna', 'Ġkole', 'Ġjeden', 'Ġz', 'Ġnej', 'lep', 'sz', 'ich', 'Ġce', 'lo', 'ro', 'czni', 'ch', 'Ġsportu', '.', 'Ġ{', '}', 'Ġz', 'wet', 'sz', 'it', 'Ġsi', 'lu', 'Ġa', 'Ġdoda', 'wa', 'Ġenergii', '.', 'Ġ', 'Ċ', 'Pro', 'Ġmno', 'he', 'Ġ_', 'Ġto', 'Ġznam', 'ena', 'Ġzacz', 'it', 'Ġod', 'Ġmali', 'czka', '.', 'Ġ', 'Ċ'] 83
