# %%
import torch
from transformers import RobertaTokenizer,RobertaModel,RobertaForMaskedLM, pipeline, BertForMaskedLM, BertTokenizer, BertModel, AlbertConfig, AlbertModel, AlbertTokenizer, AlbertForMaskedLM , TFAutoModel, AutoModelForMaskedLM, AutoTokenizer, AutoModelForCausalLM
import math
import numpy as np
import json
import random
import pandas as pd
import tensorflow as tf
from torch.nn import CrossEntropyLoss
from tqdm.notebook import tqdm
import re
from scipy.optimize import linear_sum_assignment

# %%
import sys
sys.path.append('..')
import SMI_Methods

# %%
import logging
import os
import sys
logging.basicConfig(level=logging.INFO)
import warnings
warnings.filterwarnings('ignore')

# %%
# Dictionary to map Czech characters to their Polish equivalents.
czech = {
    'č': 'cz', 
    'š': 'sz', 
    'ř': 'rz', 
    'ž': 'ż', 
    'ý': 'y', 
    'á': 'a', 
    'í': 'i', 
    'é': 'e', 
    'ě': 'e', 
    'ú': 'u', 
    'ů': 'u',
    'v': 'w'
}

slovak = {
    'á': 'o',
    'ä': 'e',
    'č': 'cz',
    'ď': 'd',
    'dz': 'dż',
    'dž': 'dż',
    'é': 'e',
    'í': 'i',
    'ľ': 'l',
    'ĺ': 'l',
    'ň': 'ń',
    'ó': 'o',
    'ô': 'u',
    'ŕ': 'r',
    'š': 'sz',
    'ť': 't',
    'ú': 'u',
    'ý': 'i',
    'ž': 'ż',
}
croatian = {
    'č': 'cz',
    'đ': 'dż',
    'dž': 'dż',
    'š': 'sz',
    'ž': 'ż',
}
slovene = {
    'č': 'cz',
    'š': 'sz',
    'ž': 'ż',
    'đ': 'dż',
}

def getKey(lang):
    d = {
        "czech":czech,
        "slovak":slovak,
        "croatian":croatian,
        "slovene":slovene
    }
    return d[lang]

def transliterate(text, lang):
    """Transcribes a text into Polish phonetically."""  
    #determine key to use
    key = getKey(lang)    
    # We need to replace longer substrings first to avoid partial matches.
    for char, polish_char in sorted(key.items(), key=lambda x: -len(x[0])):
        text = text.replace(char, polish_char)
        text = text.replace(char.upper(), polish_char.upper())  # Replace uppercase characters.
    return text

def replace_in_nested_list(nested_list,lang):
    """
    Perform the replacement operation on the deepest sublists of arbitrary depth.
    :param nested_list: The nested list to operate on
    :return: The nested list with replaced strings.
    """
    if not isinstance(nested_list, list):
        return transliterate(nested_list, lang)
    return [replace_in_nested_list(sublist, lang) for sublist in nested_list]

# %%
def count_tokens(model, tokenizer, data):
    r = 0
    for d in data:
        for s in d:
            for l in s:
                r += len(tokenizer.tokenize(l))
    return r

def see_tokens(model, tokenizer, data):
    r = 0
    for d in data:
        for s in d:
            for l in s:
                print(tokenizer.tokenize(s[l]), len(tokenizer.tokenize(s[l])))
                break

# %%
langs = ["Czech","Slovak","Croatian","Slovene"]
def token_tester(lang):
    word_list = SMI_Methods.prep_words(lang)
    data = SMI_Methods.prep_data(lang, word_list)
    print(data[0][0])
    print(count_tokens(model, tokenizer, data))
    see_tokens(model, tokenizer, data)
    print("-------------------------------------------------------------------------------")
    data = replace_in_nested_list(data, lang.lower())
    print(data[0][0])
    print(count_tokens(model, tokenizer, data))
    see_tokens(model, tokenizer, data)
    print("-------------------------------------------------------------------------------")
    print("-------------------------------------------------------------------------------")

# %%
tokenizer = AutoTokenizer.from_pretrained("sdadas/polish-gpt2-small")
model = AutoModelForCausalLM.from_pretrained("sdadas/polish-gpt2-small").cuda()

for l in langs:
    token_tester(l)
# Out:
# ['Rodiče dětí, které projevují zvýšený zájem o některý ze sportů, mají před sebou nelehké rozhodování. Měli by dětěm dovolit trénovat proto, aby z nich {} špičkoví sportovci a sportovkyně? \n', 'Pro mnohé {} to znamená začít od malička. \n', 'Škola, kamarádi a jiné zájmy musejí být {}. \n', 'Malým dětem je velmi {} vysvětlit, proč musejí trénovat pět hodin denně. \n', 'Trénink zabírá i víkendy, kdy si většina jejich kamarádů {}. \n', 'Další problém jsou samozřejmě peníze. Vlády v mnohých {} poskytují finanční prostředky nejlepším mladým atletům. \n', 'Pokud taková pomoc není dostupná, rodiče si musejí najít čas a {} na podporu svých dětí. \n', 'Sportovní oblečení, doprava na soustředění, zvláštní vybavení a jiné, mohou být velmi {}. \n', 'Mnozí rodiče si pochopitelně dělají starosti z toho, že náročný sportovní výcvik je v útlém věku nebezpečný. Někteří lékaři se shodují na tom, že ještě {} dětské svaly se tréninkem mohou poškodit. \n', 'Ale trenéři {}, že dosáhnout vrchol jako sportovec je možné, jen když se začne odmalička. \n', 'Jasné je, že jen málo lidí se {} na špičku. \n', 'Takže jak rodiče, tak děti by měli být připraveni na možnost neúspěchu. To se stává i po mnoha letech {}.\n']
# 15678
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       2 model = AutoModelForCausalLM.from_pretrained("sdadas/polish-gpt2-small").cuda()
#       4 for l in langs:
# ----> 5     token_tester(l)
#
# Cell In[27], line 7, in token_tester(lang)
#       5 print(data[0][0])
#       6 print(count_tokens(model, tokenizer, data))
# ----> 7 see_tokens(model, tokenizer, data)
#       8 print("-------------------------------------------------------------------------------")
#       9 data = replace_in_nested_list(data, lang.lower())
#
# Cell In[26], line 14, in see_tokens(model, tokenizer, data)
#      12 for s in range(1):
#      13     for l in range(1):
# ---> 14         print(tokenizer.tokenize(s[l]), len(tokenizer.tokenize(s[l])))
#
# TypeError: 'int' object is not subscriptable

# %%
model = BertForMaskedLM.from_pretrained("dkleczek/bert-base-polish-uncased-v1",ignore_mismatched_sizes=True).cuda()
tokenizer = BertTokenizer.from_pretrained("dkleczek/bert-base-polish-uncased-v1")

for l in langs:
    token_tester(l)
